# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import tkinter as tk
from tkinter import *
import matplotlib.pyplot as plt
import math
import rpack
import random
import numpy as np
import sys

np.set_printoptions(threshold=sys.maxsize)

# %%
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
class App(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title('Window')
        self.h = 1000
        self.w = 2000
        self.geometry(str(self.w)+'x'+str(self.h))
   
    def getH(self):
        return self.h
    
    def getW(self):
        return self.w
    
    def quit(self):
        self.destroy()

# %%
class Piece():
    def __init__(self):
        self.x = 0
        self.y = 0
        self.h = 0
        self.w = 0
        self.pct = 0
        
        self.tlc = []
        self.trc = []
        self.blc = []
        self.brc = []
        
    def setX(self,x):
        self.x = x
        
    def setY(self,y):
        self.y = y
        
    def setW(self,w):
        self.w = w
        
    def setH(self,h):
        self.h = h
    
    def setPct(self, pct):
        self.pct = pct
    
    def setTlc(self, tlc):
        self.tlc = tlc
    
    def getTlc(self):
        self.tlc = [self.x, self.y]
        return self.tlc
    
    def getTrc(self):
        self.trc = [self.x+self.w, self.y]
        return self.trc
    
    def getBlc(self):
        self.blc = [self.x, self.y+self.h]
        return self.blc
    
    def getBrc(self):
        self.brc = [self.x+self.w, self.y+self.h]
        return self.brc    
    
class Chambre(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15
        self.num = 1
        self.col = "orange"
    
    def __str__(self):
        return "Chambre"
        
class Cuisine(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15
        self.num = 2
        self.col = "green"
        
    def __str__(self):
        return "Cuisine"
        
class Sam(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15    
        self.num = 3
        self.col = "purple"
        
    def __str__(self):
        return "Salle à manger"
    
class Sdb(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 10
        self.num = 4
        self.col = "blue"
    
    def __str__(self):
        return "Salle de bain"
        
class Toilettes(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 5
        self.col = "grey"
        
    def __str__(self):
        return "Toilettes"
        
class Rangement(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 6
        self.col = "maroon"
    
    def __str__(self):
        return "Rangement"
    
class Buanderie(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 7
        self.col = "cyan"
        
    def __str__(self):
        return "Buanderie"

class Entree(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        #self.pct = 15
        self.num = 8
        self.col = "yellow"
    
    def __str__(self):
        return "EntréeS"    

def tabModulo(n):
    n = n
    l = []
    
    #print(n)
    
    for i in range (1,n+1):
        if n%i == 0 and i != 1 and i != n:
            l.append(i)
            
    nl = l[::-1]
    tab = pd.DataFrame(l, columns = [1])
    tab[2] = nl
    #display(tab)
    
    return tab

# %%
class Appartement():
    def __init__(self, app, h, w):
        self.app = app
        self.x = 150
        self.y = 50
        self.h = h
        self.w = w
        self.listePieces = []
        
        self.tlc = [self.x, self.y, "TLC"]
        self.trc = [self.x+self.w, self.y, "TRC"]
        self.blc = [self.x, self.y+self.h, "BLC"]
        self.brc = [self.x+self.w, self.y+self.h, "BRC"]
        
        self.ent = Entree()
        
        self.mat = np.zeros((self.w, self.h))
        
        self.can = tk.Canvas(self.app, bg = "white", height = app.getH(), width = app.getW())
        
    def afficherAppartement(self):
        self.can.create_rectangle(self.x, self.y, 
                             self.x+self.w, self.y+self.h)
        
                             #fill = "white" )
        #can.create_polygon(self.x, self.y,
        #                   (self.x+self.w)-(self.x+self.w)/4, self.y,
        #                   (self.x+self.w)-(self.x+self.w)/4, self.y+(self.x+self.w)/6,
        #                   self.x+self.w, self.y+(self.x+self.w)/6,
        #                   self.x+self.w, self.y + self.h,
        #                   self.x, self.y + self.h, 
        #                   outline = "black",
        #                   fill = "white" )
        
        self.ent.setX((self.x+(self.w)/2)-25)
        self.ent.setY(self.y)
        self.ent.setW(50)
        self.ent.setH(self.y)
        tlc = self.ent.getTlc()
        brc = self.ent.getBrc()
        self.can.create_rectangle(tlc[0],tlc[1],brc[0],brc[1], outline = "black")
        
        self.can.create_line((self.x+(self.w)/2)-17, self.y,(self.x+(self.w)/2)+17, self.y, fill = "white")
        self.can.pack()
    
    def afficherGrille(self):
        self.dimcase = math.sqrt((5*(self.h*self.w))/100)
        self.nbcasesh = int(self.h/self.dimcase)
        self.nbcasesw = int(self.w/self.dimcase)
        #print(self.dimcase)
        #print(self.nbcasesh)
        #print(self.nbcasesw)
        for i in range(self.nbcasesh):
            for j in range(self.nbcasesw):
                #print(i)
                self.can.create_rectangle(self.x+j*self.dimcase, self.y+i*self.dimcase, self.x+(j+1)*self.dimcase, self.y+(i+1)*self.dimcase, outline = 'red')
        
        self.can.pack()
    
    def drawRoom(self, tlc, brc, piece):
        self.can.create_rectangle(tlc[0],tlc[1],brc[0],brc[1], outline = "green")
        self.can.create_text(tlc[0]+(piece.w/2),tlc[1]+(piece.h/2),fill="black",font="Times 8",text=f"{piece.__str__()}")
        
    
    def createRooms(self):      
        chb = Chambre()
        csn = Cuisine()
        sdb = Sdb()
        sam = Sam()
        tlt = Toilettes()
        rng = Rangement()
        bdr = Buanderie()
        
        self.listePieces = [chb,csn,sdb,sam,tlt,rng,bdr]
        random.shuffle(self.listePieces)
        
        totalpct = 100
        
        idx = 0
        sumW = 0
        for piece in self.listePieces:
            piece.setX(self.x)
            piece.setY(self.y)
            

            if piece.pct == 5:
                rndpct = random.randrange(0,6,5)
            else:
                rndpct = random.randrange(-5,6,5)
                
            if totalpct > 15:
                piece.setPct(piece.pct+rndpct)
            
            totalpct = totalpct-(piece.pct+rndpct)
            
            #print(piece.__str__()+" "+str(piece.pct))
            #print(totalpct)
            
            dimcase = int((piece.pct*(self.h*self.w))/100)
            tab = tabModulo(dimcase)
            
            for i in range(2):
                dimliste = [self.w, self.h]
                indexModuloLow = tab[tab[i+1] < 100].index
                indexModuloHigh = tab[tab[i+1] > dimliste[i]].index
                tab.drop(indexModuloLow, inplace = True)
                tab.drop(indexModuloHigh, inplace = True)
                
            #display(tab)
            
            rnddim = random.choice(tab.values.tolist())
            #print(rnddim)
            
            piece.setW(rnddim[0])
            piece.setH(rnddim[1])
            
            sumW = sumW+piece.w
            tlc = [piece.x+(sumW-piece.w),piece.y+450]
            brc = [piece.x+sumW, piece.y+450+piece.h]
            
            self.drawRoom(tlc, brc, piece)
            
            idx += 1
        
        self.can.pack()
        
    def placeRooms(self):
        L = self.listePieces
        placed = []
        done = 0
        sumW = 0
        sumH = 0
        k = 0
        
        while len(placed) != len(L):
            for piece in L:
                if self.x+piece.w < (self.x+(self.w)/2)-17 and done == 0:
                    piece.setX(self.x)
                    piece.setY(self.y)
                    
                    self.drawRoom(piece.getTlc(), piece.getBrc(), piece)
                                        
                    done = 1
                    sumW = piece.w
                    sumH = piece.h
                    placed.append(piece)
                    
                    #self.majMatrice(piece)
                    #self.app.update()
                    #input("Press Enter to continue...")
                    
                if piece in placed:
                    #print(placed)
                    for piece2 in L:
                        #print((self.x+(self.w)/2)-17)
                        if piece2.__str__() != piece.__str__() and sumH + piece2.h <= self.h and piece2 not in placed:
                            tlc = piece.getBlc()
                            piece2.setX(tlc[0])
                            piece2.setY(tlc[1])
                            
                            self.drawRoom(piece2.getTlc(), piece2.getBrc(), piece2)
                            
                            placed.append(piece2)
                            sumH = sumH + piece2.h
                            
                            #self.majMatrice(piece2)
                            #self.app.update()
                            
                            break
                            
                    for piece2 in L:
                        if piece.y != self.y:
                            lim = self.w
                        else:
                            lim = ((self.w)/2)-17
                            
                        if piece2.__str__() != piece.__str__() and sumW + piece2.w <= lim and piece2 not in placed:
                            tlc = piece.getTrc()
                            piece2.setX(tlc[0])
                            piece2.setY(tlc[1])

                            self.drawRoom(piece2.getTlc(), piece2.getBrc(), piece2)

                            placed.append(piece2)
                            sumW = sumW + piece2.w
                            
                            #self.majMatrice(piece2)
                            #self.app.update()
                            
                            break
                            
                    print("ite "+str(k))
                    for p in placed:
                        print(p.__str__())
                        
                    k+=1
                    
            placed = L 
                
            self.can.pack()
    
    def placeRooms2(self):
        #entTlc = self.ent.getTlc() + ['TRC']
        #entTrc = self.ent.getTrc() + ['TLC']
        #entBlc = self.ent.getBlc() + ['BLC']
        #entBrc = self.ent.getBrc() + ['BRC']
        
        listeCoins = [self.tlc,self.trc,self.brc,self.blc]        
        
        for piece in self.listePieces:
            listeCoinsPiece = [piece.getTrc(),piece.getTlc(),piece.getBrc(),piece.getBlc()]
            coin = random.choice(listeCoins)
            print(piece.__str__())
            print(listeCoins)
            print(coin)
            #print([coin[0]-self.x,coin[1]-self.y,coin[2]])
            
            if coin[2] == "TLC":
                piece.setX(coin[0])
                piece.setY(coin[1])
                
                trc = piece.getTrc() + ['TLC']
                blc = piece.getBlc() + ['TLC']
                
                listeCoins.append(trc)
                listeCoins.append(blc)
                listeCoins.remove(coin)

            if coin[2] == "TRC":
                piece.setX(coin[0]-piece.w)
                piece.setY(coin[1])
                
                tlc = piece.getTlc() + ['TRC']
                brc = piece.getBrc() + ['TRC']

                listeCoins.append(tlc)
                listeCoins.append(brc)
                listeCoins.remove(coin)

            if coin[2] == "BLC":
                piece.setX(coin[0])
                piece.setY(coin[1]-piece.h)
                
                tlc = piece.getTlc() + ['BLC']
                brc = piece.getBrc() + ['BLC']
                
                listeCoins.append(tlc)
                listeCoins.append(brc)
                listeCoins.remove(coin)

            if coin[2] == "BRC":
                piece.setX(coin[0]-piece.w)
                piece.setY(coin[1]-piece.h)
                
                trc = piece.getTrc() + ['BRC']
                blc = piece.getBlc() + ['BRC']
                
                listeCoins.append(trc)
                listeCoins.append(blc)
                listeCoins.remove(coin)
            
            for coinpiece in listeCoinsPiece:
                for coinliste in listeCoins:
                    if coinpiece[0] == coinliste[0] and coinpiece[1] == coinliste[1]:
                        listeCoins.remove(coinliste)
                    
            self.drawRoom(piece.getTlc(), piece.getBrc(), piece)
            #self.majMatrice(piece)
            
        self.can.pack()
    
    def majMatrice(self, piece):
        x = piece.x - self.x
        y = piece.y - self.y
        brc = piece.getBrc()
        print(piece.__str__(), piece.num)
        print([x,y])
        print([piece.w,piece.h])
        print([x+piece.w,y+piece.h])
        
        W = x+piece.w
        H = y+piece.h
        xi = x
        yi = y
        
        self.can.create_rectangle(self.x+self.w+200, self.y, 
                             self.x+self.w*2+200, self.y+self.h)        
        #self.can.create_line((self.x+(self.w)/2)-17, self.y,(self.x+(self.w)/2)+17, self.y, fill = "white")
        self.can.pack()
        
        while xi < W:
            #print(xi)
            yi = y
            while yi < H:
                #print(yi)
                self.mat[xi][yi] = self.mat[xi][yi]*7+piece.num
                self.can.create_text(self.x+xi+self.w+200,self.y+yi,fill=piece.col,font="Arial 1",text=f"{self.mat[xi][yi]}")
                
                yi += 1
            xi += 1
    
    def afficherMatrice(self):
        print(len(self.mat))
        print(self.mat)
        
        return self.mat
    
    def getSurface(self):
        return self.h*self.w
    
    def getCoordoAppart(self):
        return self.x , self.y, self.h, self.w

# %%
app = App()

A1 = Appartement(app, 400,500)
#A1.afficherGrille()
A1.afficherAppartement()
A1.createRooms()
A1.placeRooms2()
#wat = A1.afficherMatrice()
#tabModulo(172)

app.mainloop()
# Out:
# Chambre
# [[150, 50, 'TLC'], [650, 50, 'TRC'], [650, 450, 'BRC'], [150, 450, 'BLC']]
# [650, 450, 'BRC']
# Toilettes
# [[650, 50, 'TRC'], [150, 450, 'BLC'], [650, 200, 'BRC'], [530, 450, 'BRC']]
# [530, 450, 'BRC']
# Cuisine
# [[650, 50, 'TRC'], [150, 450, 'BLC'], [650, 200, 'BRC'], [530, 325, 'BRC'], [370, 450, 'BRC']]
# [650, 50, 'TRC']
# Buanderie
# [[150, 450, 'BLC'], [650, 200, 'BRC'], [530, 325, 'BRC'], [370, 450, 'BRC'], [450, 50, 'TRC'], [650, 150, 'TRC']]
# [370, 450, 'BRC']
# Salle à manger
# [[150, 450, 'BLC'], [650, 200, 'BRC'], [530, 325, 'BRC'], [450, 50, 'TRC'], [650, 150, 'TRC'], [370, 350, 'BRC'], [270, 450, 'BRC']]
# [370, 350, 'BRC']
# Rangement
# [[150, 450, 'BLC'], [650, 200, 'BRC'], [530, 325, 'BRC'], [450, 50, 'TRC'], [650, 150, 'TRC'], [270, 450, 'BRC'], [370, 230, 'BRC'], [120, 350, 'BRC']]
# [650, 200, 'BRC']
# Salle de bain
# [[150, 450, 'BLC'], [530, 325, 'BRC'], [450, 50, 'TRC'], [650, 150, 'TRC'], [270, 450, 'BRC'], [370, 230, 'BRC'], [120, 350, 'BRC'], [650, 100, 'BRC'], [550, 200, 'BRC']]
# [150, 450, 'BLC']

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

point = Point(0.5, 0.5)
polygon = Polygon([(0, 0), (0, 0.4), (0.2, 0.4), (0.2, 1), (1, 1), (1, 0)])
print(polygon.contains(point))
# Out:
# True

# %%
plt.plot(*polygon.exterior.xy)

# %%
sizes = [(58, 206), (231, 176), (35, 113), (46, 109)]
positions = rpack.pack(sizes)
positions
poly1 = Polygon(positions)
plt.plot(*poly1.exterior.xy)
