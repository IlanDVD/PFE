# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import tkinter as tk
from tkinter import *
import matplotlib.pyplot as plt
import math
import rpack
import random
import numpy as np
import sys

np.set_printoptions(threshold=sys.maxsize)

# %%
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
class App(tk.Tk):
    def __init__(self):
        super().__init__()

        self.title('Window')
        self.h = 1000
        self.w = 2000
        self.geometry(str(self.w)+'x'+str(self.h))
   
    def getH(self):
        return self.h
    
    def getW(self):
        return self.w
    
    def quit(self):
        self.destroy()

# %%
class Piece():
    def __init__(self):
        self.x = 0
        self.y = 0
        self.h = 0
        self.w = 0
        self.pct = 0
        
        self.tlc = []
        self.trc = []
        self.blc = []
        self.brc = []
        
    def setX(self,x):
        self.x = x
        
    def setY(self,y):
        self.y = y
        
    def setW(self,w):
        self.w = w
        
    def setH(self,h):
        self.h = h
    
    def setPct(self, pct):
        self.pct = pct
    
    def setTlc(self, tlc):
        self.tlc = tlc
    
    def getTlc(self):
        self.tlc = [self.x, self.y]
        return self.tlc
    
    def getTrc(self):
        self.trc = [self.x+self.w, self.y]
        return self.trc
    
    def getBlc(self):
        self.blc = [self.x, self.y+self.h]
        return self.blc
    
    def getBrc(self):
        self.brc = [self.x+self.w, self.y+self.h]
        return self.brc
    
class Chambre(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15
        self.num = 1
        self.col = "orange"
    
    def __str__(self):
        return "Chambre"
        
class Cuisine(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15
        self.num = 2
        self.col = "green"
        
    def __str__(self):
        return "Cuisine"
        
class Sam(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 15    
        self.num = 3
        self.col = "purple"
        
    def __str__(self):
        return "Salle à manger"
    
class Sdb(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 10
        self.num = 4
        self.col = "blue"
    
    def __str__(self):
        return "Salle de bain"
        
class Toilettes(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 5
        self.col = "grey"
        
    def __str__(self):
        return "Toilettes"
        
class Rangement(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 6
        self.col = "maroon"
    
    def __str__(self):
        return "Rangement"
    
class Buanderie(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        self.pct = 5
        self.num = 7
        self.col = "cyan"
        
    def __str__(self):
        return "Buanderie"

class Entree(Piece):
    def __init__(self):
        Piece.__init__(self)
        self.h = 100
        self.w = 100
        #self.pct = 15
        self.num = 8
        self.col = "yellow"
    
    def __str__(self):
        return "EntréeS"    

def tabModulo(n):
    n = n
    l = []
    
    #print(n)
    
    for i in range (1,n+1):
        if n%i == 0 and i != 1 and i != n:
            l.append(i)
            
    nl = l[::-1]
    tab = pd.DataFrame(l, columns = [1])
    tab[2] = nl
    #display(tab)
    
    return tab

# %%
class Appartement():
    def __init__(self, app, h, w):
        self.app = app
        self.x = 150
        self.y = 50
        self.h = h
        self.w = w
        self.listePieces = []
        
        self.tlc = [self.x, self.y, "TLC"]
        self.trc = [self.x+self.w, self.y, "TRC"]
        self.blc = [self.x, self.y+self.h, "BLC"]
        self.brc = [self.x+self.w, self.y+self.h, "BRC"]
        
        self.ent = Entree()
        
        self.mat = np.zeros((self.w, self.h))
        
        self.can = tk.Canvas(self.app, bg = "white", height = app.getH(), width = app.getW())
        
    def afficherAppartement(self):
        self.can.create_rectangle(self.x, self.y, 
                             self.x+self.w, self.y+self.h)
        
                             #fill = "white" )
        #can.create_polygon(self.x, self.y,
        #                   (self.x+self.w)-(self.x+self.w)/4, self.y,
        #                   (self.x+self.w)-(self.x+self.w)/4, self.y+(self.x+self.w)/6,
        #                   self.x+self.w, self.y+(self.x+self.w)/6,
        #                   self.x+self.w, self.y + self.h,
        #                   self.x, self.y + self.h, 
        #                   outline = "black",
        #                   fill = "white" )
        
        self.ent.setX((self.x+(self.w)/2)-25)
        self.ent.setY(self.y)
        self.ent.setW(50)
        self.ent.setH(self.y)
        tlc = self.ent.getTlc()
        brc = self.ent.getBrc()
        self.can.create_rectangle(tlc[0],tlc[1],brc[0],brc[1], outline = "black")
        
        self.can.create_line((self.x+(self.w)/2)-17, self.y,(self.x+(self.w)/2)+17, self.y, fill = "white")
        self.can.pack()
    
    def afficherGrille(self):
        self.dimcase = math.sqrt((5*(self.h*self.w))/100)
        self.nbcasesh = int(self.h/self.dimcase)
        self.nbcasesw = int(self.w/self.dimcase)
        #print(self.dimcase)
        #print(self.nbcasesh)
        #print(self.nbcasesw)
        for i in range(self.nbcasesh):
            for j in range(self.nbcasesw):
                #print(i)
                self.can.create_rectangle(self.x+j*self.dimcase, self.y+i*self.dimcase, self.x+(j+1)*self.dimcase, self.y+(i+1)*self.dimcase, outline = 'red')
        
        self.can.pack()
    
    def drawRoom(self, tlc, brc, piece):
        self.can.create_rectangle(tlc[0],tlc[1],brc[0],brc[1], outline = "green")
        self.can.create_text(tlc[0]+(piece.w/2),tlc[1]+(piece.h/2),fill="black",font="Times 8",text=f"{piece.__str__()}")
        
    
    def createRooms(self):      
        chb = Chambre()
        csn = Cuisine()
        sdb = Sdb()
        sam = Sam()
        tlt = Toilettes()
        rng = Rangement()
        bdr = Buanderie()
        
        #self.listePieces = [chb,csn,sdb,sam,tlt,rng,bdr]
        self.listePieces = [chb,csn,sdb,sam,tlt]
        random.shuffle(self.listePieces)
        
        totalpct = 100
        
        idx = 0
        sumW = 0
        for piece in self.listePieces:
            piece.setX(self.x)
            piece.setY(self.y)
            

            if piece.pct == 5:
                rndpct = random.randrange(0,6,5)
            else:
                rndpct = random.randrange(-5,6,5)
                
            if totalpct > 15:
                piece.setPct(piece.pct+rndpct)
            
            totalpct = totalpct-(piece.pct+rndpct)
            
            #print(piece.__str__()+" "+str(piece.pct))
            #print(totalpct)
            
            dimcase = int((piece.pct*(self.h*self.w))/100)
            tab = tabModulo(dimcase)
            
            for i in range(2):
                dimliste = [self.w, self.h]
                indexModuloLow = tab[tab[i+1] < 100].index
                indexModuloHigh = tab[tab[i+1] > dimliste[i]].index
                tab.drop(indexModuloLow, inplace = True)
                tab.drop(indexModuloHigh, inplace = True)
                
            #display(tab)
            
            rnddim = random.choice(tab.values.tolist())
            #print(rnddim)
            
            piece.setW(rnddim[0])
            piece.setH(rnddim[1])
            
            sumW = sumW+piece.w
            tlc = [piece.x+(sumW-piece.w),piece.y+450]
            brc = [piece.x+sumW, piece.y+450+piece.h]
            
            self.drawRoom(tlc, brc, piece)
            
            idx += 1
        
        self.can.pack()
        
    def placeRooms(self):
        L = self.listePieces
        placed = []
        done = 0
        sumW = 0
        sumH = 0
        k = 0
        
        while len(placed) != len(L):
            for piece in L:
                if self.x+piece.w < (self.x+(self.w)/2)-17 and done == 0:
                    piece.setX(self.x)
                    piece.setY(self.y)
                    
                    self.drawRoom(piece.getTlc(), piece.getBrc(), piece)
                                        
                    done = 1
                    sumW = piece.w
                    sumH = piece.h
                    placed.append(piece)
                    
                    #self.majMatrice(piece)
                    #self.app.update()
                    #input("Press Enter to continue...")
                    
                if piece in placed:
                    #print(placed)
                    for piece2 in L:
                        #print((self.x+(self.w)/2)-17)
                        if piece2.__str__() != piece.__str__() and sumH + piece2.h <= self.h and piece2 not in placed:
                            tlc = piece.getBlc()
                            piece2.setX(tlc[0])
                            piece2.setY(tlc[1])
                            
                            self.drawRoom(piece2.getTlc(), piece2.getBrc(), piece2)
                            
                            placed.append(piece2)
                            sumH = sumH + piece2.h
                            
                            #self.majMatrice(piece2)
                            #self.app.update()
                            
                            break
                            
                    for piece2 in L:
                        if piece.y != self.y:
                            lim = self.w
                        else:
                            lim = ((self.w)/2)-17
                            
                        if piece2.__str__() != piece.__str__() and sumW + piece2.w <= lim and piece2 not in placed:
                            tlc = piece.getTrc()
                            piece2.setX(tlc[0])
                            piece2.setY(tlc[1])

                            self.drawRoom(piece2.getTlc(), piece2.getBrc(), piece2)

                            placed.append(piece2)
                            sumW = sumW + piece2.w
                            
                            #self.majMatrice(piece2)
                            #self.app.update()
                            
                            break
                            
                    print("ite "+str(k))
                    for p in placed:
                        print(p.__str__())
                        
                    k+=1
                    
            placed = L 
                
            self.can.pack()
    
    def f(self, piece, listeCoins, placed):
            listeCoinsPotentiels = []
            coin = random.choice(listeCoins)
            print(piece.__str__())
            print(listeCoins)
            print(coin)
            #print([coin[0]-self.x,coin[1]-self.y,coin[2]])
            
            if coin[2] == "TLC":
                piece.setX(coin[0])
                piece.setY(coin[1])
                
                trc = piece.getTrc() + ['TLC']
                blc = piece.getBlc() + ['TLC']
                
                listeCoinsPotentiels.append(trc)
                listeCoinsPotentiels.append(blc)

            if coin[2] == "TRC":
                piece.setX(coin[0]-piece.w)
                piece.setY(coin[1])
                
                tlc = piece.getTlc() + ['TRC']
                brc = piece.getBrc() + ['TRC']

                listeCoinsPotentiels.append(tlc)
                listeCoinsPotentiels.append(brc)

            if coin[2] == "BLC":
                piece.setX(coin[0])
                piece.setY(coin[1]-piece.h)
                
                tlc = piece.getTlc() + ['BLC']
                brc = piece.getBrc() + ['BLC']
                
                listeCoinsPotentiels.append(tlc)
                listeCoinsPotentiels.append(brc)

            if coin[2] == "BRC":
                piece.setX(coin[0]-piece.w)
                piece.setY(coin[1]-piece.h)
                
                trc = piece.getTrc() + ['BRC']
                blc = piece.getBlc() + ['BRC']
                
                listeCoinsPotentiels.append(trc)
                listeCoinsPotentiels.append(blc)
            
            listeCoinsPiece = [piece.getTrc(),piece.getTlc(),piece.getBrc(),piece.getBlc()]
            horsChamps = 0
            superposition = 0
            
            for coinpiece in listeCoinsPiece:
                print(listeCoinsPiece)
                for coinliste in listeCoins:
                    if coinpiece[0] == coinliste[0] and coinpiece[1] == coinliste[1]:
                        print(f"Remove : {coinliste}")
                        #listeCoins.remove(coinliste)
                    
            
                if coinpiece[0] < self.x or coinpiece[0] > self.x+self.w or coinpiece[1] < self.y or coinpiece[1] > self.y+self.h:
                    horsChamps = 1
                    
            for placedpiece in placed:
                pptrc, pptlc, ppbrc, ppblc = placedpiece.getTrc(),placedpiece.getTlc(),placedpiece.getBrc(),placedpiece.getBlc()
                for coinpiece in listeCoinsPiece:
                    if (coinpiece[0] <= pptrc[0] and coinpiece[0] >= pptlc[0] and coinpiece[0] <= ppbrc[0] and coinpiece[0] >= ppblc[0]) and (coinpiece[1] >= pptrc[1] and coinpiece[1] >= pptlc[1] and coinpiece[1] <= ppbrc[1] and coinpiece[1] <= ppblc[1]):
                        superposition = 1
            
            if horsChamps == 1 or superposition == 1:
                listeCoins.remove(coin)
                print("REITERATION")
                self.f(piece, listeCoins, placed)
                listeCoins.append(coin)
            else:
                listeCoins.remove(coin)
                self.drawRoom(piece.getTlc(), piece.getBrc(), piece)
                placed.append(piece)
                for coin in listeCoinsPotentiels:
                    listeCoins.append(coin)
            #self.majMatrice(piece)
    
    def placeRooms2(self):
        #entTlc = self.ent.getTlc() + ['TRC']
        #entTrc = self.ent.getTrc() + ['TLC']
        #entBlc = self.ent.getBlc() + ['BLC']
        #entBrc = self.ent.getBrc() + ['BRC']
        placed = [self.ent]
        listeCoins = [self.tlc,self.trc,self.brc,self.blc]        
        
        for piece in self.listePieces:
            self.f(piece, listeCoins, placed)
            
            
        self.can.pack()
    
    def majMatrice(self, piece):
        x = piece.x - self.x
        y = piece.y - self.y
        brc = piece.getBrc()
        print(piece.__str__(), piece.num)
        print([x,y])
        print([piece.w,piece.h])
        print([x+piece.w,y+piece.h])
        
        W = x+piece.w
        H = y+piece.h
        xi = x
        yi = y
        
        self.can.create_rectangle(self.x+self.w+200, self.y, 
                             self.x+self.w*2+200, self.y+self.h)        
        #self.can.create_line((self.x+(self.w)/2)-17, self.y,(self.x+(self.w)/2)+17, self.y, fill = "white")
        self.can.pack()
        
        while xi < W:
            #print(xi)
            yi = y
            while yi < H:
                #print(yi)
                self.mat[xi][yi] = self.mat[xi][yi]*7+piece.num
                self.can.create_text(self.x+xi+self.w+200,self.y+yi,fill=piece.col,font="Arial 1",text=f"{self.mat[xi][yi]}")
                
                yi += 1
            xi += 1
    
    def afficherMatrice(self):
        print(len(self.mat))
        print(self.mat)
        
        return self.mat
    
    def getSurface(self):
        return self.h*self.w
    
    def getCoordoAppart(self):
        return self.x , self.y, self.h, self.w

# %%
app = App()

A1 = Appartement(app, 400,500)
#A1.afficherGrille()
A1.afficherAppartement()
A1.createRooms()
A1.placeRooms2()
#wat = A1.afficherMatrice()
#tabModulo(172)

app.mainloop()
# Out:
# Salle à manger
# [[150, 50, 'TLC'], [650, 50, 'TRC'], [650, 450, 'BRC'], [150, 450, 'BLC']]
# [150, 450, 'BLC']
# [[350, 300], [150, 300], [350, 450], [150, 450]]
# [[350, 300], [150, 300], [350, 450], [150, 450]]
# Remove : [150, 300, 'BLC']
# [[350, 300], [150, 300], [350, 450], [150, 450]]
# Remove : [350, 450, 'BLC']
# [[350, 300], [150, 300], [350, 450], [150, 450]]
# Salle de bain
# [[150, 50, 'TLC'], [650, 50, 'TRC'], [650, 450, 'BRC'], [150, 300, 'BLC'], [350, 450, 'BLC']]
# [150, 300, 'BLC']
# [[250, 200], [150, 200], [250, 300], [150, 300]]
# [[250, 200], [150, 200], [250, 300], [150, 300]]
# Remove : [150, 200, 'BLC']
# [[250, 200], [150, 200], [250, 300], [150, 300]]
# Remove : [250, 300, 'BLC']
# [[250, 200], [150, 200], [250, 300], [150, 300]]
# REITERATION
# Salle de bain
# [[150, 50, 'TLC'], [650, 50, 'TRC'], [650, 450, 'BRC'], [350, 450, 'BLC'], [150, 200, 'BLC'], [250, 300, 'BLC']]
# [350, 450, 'BLC']
# [[450, 350], [350, 350], [450, 450], [350, 450]]
# [[450, 350], [350, 350], [450, 450], [350, 450]]
# Remove : [350, 350, 'BLC']
# [[450, 350], [350, 350], [450, 450], [350, 450]]
# Remove : [450, 450, 'BLC']
# [[450, 350], [350, 350], [450, 450], [350, 450]]
# REITERATION
# Salle de bain
# [[150, 50, 'TLC'], [650, 50, 'TRC'], [650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [450, 450, 'BLC']]
# [650, 50, 'TRC']
# [[650, 50], [550, 50], [650, 150], [550, 150]]
# [[650, 50], [550, 50], [650, 150], [550, 150]]
# Remove : [550, 50, 'TRC']
# [[650, 50], [550, 50], [650, 150], [550, 150]]
# Remove : [650, 150, 'TRC']
# [[650, 50], [550, 50], [650, 150], [550, 150]]
# Chambre
# [[150, 50, 'TLC'], [650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [450, 450, 'BLC'], [550, 50, 'TRC'], [650, 150, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC']]
# [650, 150, 'TRC']
# [[650, 150], [400, 150], [650, 270], [400, 270]]
# [[650, 150], [400, 150], [650, 270], [400, 270]]
# Remove : [400, 150, 'TRC']
# [[650, 150], [400, 150], [650, 270], [400, 270]]
# Remove : [650, 270, 'TRC']
# [[650, 150], [400, 150], [650, 270], [400, 270]]
# REITERATION
# Chambre
# [[150, 50, 'TLC'], [650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [450, 450, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [400, 150, 'TRC'], [650, 270, 'TRC']]
# [150, 50, 'TLC']
# [[400, 50], [150, 50], [400, 170], [150, 170]]
# Remove : [400, 50, 'TLC']
# [[400, 50], [150, 50], [400, 170], [150, 170]]
# [[400, 50], [150, 50], [400, 170], [150, 170]]
# [[400, 50], [150, 50], [400, 170], [150, 170]]
# Remove : [150, 170, 'TLC']
# Cuisine
# [[650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [450, 450, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [400, 150, 'TRC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [150, 170, 'TLC'], [650, 150, 'TRC']]
# [450, 450, 'BLC']
# [[610, 325], [450, 325], [610, 450], [450, 450]]
# [[610, 325], [450, 325], [610, 450], [450, 450]]
# Remove : [450, 325, 'BLC']
# [[610, 325], [450, 325], [610, 450], [450, 450]]
# Remove : [610, 450, 'BLC']
# [[610, 325], [450, 325], [610, 450], [450, 450]]
# Toilettes
# [[650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [400, 150, 'TRC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [150, 170, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC']]
# [150, 170, 'TLC']
# [[350, 170], [150, 170], [350, 270], [150, 270]]
# Remove : [350, 170, 'TLC']
# [[350, 170], [150, 170], [350, 270], [150, 270]]
# [[350, 170], [150, 170], [350, 270], [150, 270]]
# [[350, 170], [150, 170], [350, 270], [150, 270]]
# Remove : [150, 270, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [400, 150, 'TRC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC']]
# [400, 150, 'TRC']
# [[400, 150], [200, 150], [400, 250], [200, 250]]
# [[400, 150], [200, 150], [400, 250], [200, 250]]
# Remove : [200, 150, 'TRC']
# [[400, 150], [200, 150], [400, 250], [200, 250]]
# Remove : [400, 250, 'TRC']
# [[400, 150], [200, 150], [400, 250], [200, 250]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [150, 200, 'BLC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC']]
# [150, 200, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# Remove : [150, 100, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# Remove : [350, 200, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [150, 100, 'BLC'], [350, 200, 'BLC']]
# [150, 100, 'BLC']
# [[350, 0], [150, 0], [350, 100], [150, 100]]
# [[350, 0], [150, 0], [350, 100], [150, 100]]
# Remove : [150, 0, 'BLC']
# [[350, 0], [150, 0], [350, 100], [150, 100]]
# Remove : [350, 100, 'BLC']
# [[350, 0], [150, 0], [350, 100], [150, 100]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [250, 300, 'BLC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC']]
# [250, 300, 'BLC']
# [[450, 200], [250, 200], [450, 300], [250, 300]]
# [[450, 200], [250, 200], [450, 300], [250, 300]]
# Remove : [250, 200, 'BLC']
# [[450, 200], [250, 200], [450, 300], [250, 300]]
# Remove : [450, 300, 'BLC']
# [[450, 200], [250, 200], [450, 300], [250, 300]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [550, 50, 'TRC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC']]
# [550, 50, 'TRC']
# [[550, 50], [350, 50], [550, 150], [350, 150]]
# [[550, 50], [350, 50], [550, 150], [350, 150]]
# Remove : [350, 50, 'TRC']
# [[550, 50], [350, 50], [550, 150], [350, 150]]
# Remove : [550, 150, 'TRC']
# [[550, 50], [350, 50], [550, 150], [350, 150]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [350, 450, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC']]
# [350, 450, 'BLC']
# [[550, 350], [350, 350], [550, 450], [350, 450]]
# [[550, 350], [350, 350], [550, 450], [350, 450]]
# Remove : [350, 350, 'BLC']
# Remove : [350, 350, 'BLC']
# [[550, 350], [350, 350], [550, 450], [350, 450]]
# Remove : [550, 450, 'BLC']
# [[550, 350], [350, 350], [550, 450], [350, 450]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [350, 170, 'TLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 450, 'BLC']]
# [350, 170, 'TLC']
# [[550, 170], [350, 170], [550, 270], [350, 270]]
# Remove : [550, 170, 'TLC']
# [[550, 170], [350, 170], [550, 270], [350, 270]]
# [[550, 170], [350, 170], [550, 270], [350, 270]]
# [[550, 170], [350, 170], [550, 270], [350, 270]]
# Remove : [350, 270, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 450, 'BLC'], [550, 170, 'TLC'], [350, 270, 'TLC']]
# [350, 270, 'TLC']
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# Remove : [550, 270, 'TLC']
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# Remove : [350, 370, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 450, 'BLC'], [550, 170, 'TLC'], [550, 270, 'TLC'], [350, 370, 'TLC']]
# [550, 450, 'BLC']
# [[750, 350], [550, 350], [750, 450], [550, 450]]
# [[750, 350], [550, 350], [750, 450], [550, 450]]
# Remove : [550, 350, 'BLC']
# [[750, 350], [550, 350], [750, 450], [550, 450]]
# Remove : [750, 450, 'BLC']
# [[750, 350], [550, 350], [750, 450], [550, 450]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [150, 270, 'TLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 170, 'TLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC']]
# [150, 270, 'TLC']
# [[350, 270], [150, 270], [350, 370], [150, 370]]
# Remove : [350, 270, 'TLC']
# [[350, 270], [150, 270], [350, 370], [150, 370]]
# [[350, 270], [150, 270], [350, 370], [150, 370]]
# Remove : [350, 370, 'TLC']
# [[350, 270], [150, 270], [350, 370], [150, 370]]
# Remove : [150, 370, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [200, 150, 'TRC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 170, 'TLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC']]
# [200, 150, 'TRC']
# [[200, 150], [0, 150], [200, 250], [0, 250]]
# [[200, 150], [0, 150], [200, 250], [0, 250]]
# Remove : [0, 150, 'TRC']
# [[200, 150], [0, 150], [200, 250], [0, 250]]
# Remove : [200, 250, 'TRC']
# [[200, 150], [0, 150], [200, 250], [0, 250]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 170, 'TLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC']]
# [550, 170, 'TLC']
# [[750, 170], [550, 170], [750, 270], [550, 270]]
# Remove : [750, 170, 'TLC']
# [[750, 170], [550, 170], [750, 270], [550, 270]]
# [[750, 170], [550, 170], [750, 270], [550, 270]]
# [[750, 170], [550, 170], [750, 270], [550, 270]]
# Remove : [550, 270, 'TLC']
# Remove : [550, 270, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC']]
# [550, 270, 'TLC']
# [[750, 270], [550, 270], [750, 370], [550, 370]]
# Remove : [750, 270, 'TLC']
# [[750, 270], [550, 270], [750, 370], [550, 370]]
# Remove : [550, 270, 'TLC']
# [[750, 270], [550, 270], [750, 370], [550, 370]]
# [[750, 270], [550, 270], [750, 370], [550, 370]]
# Remove : [550, 370, 'TLC']
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [350, 200, 'BLC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC']]
# [350, 200, 'BLC']
# [[550, 100], [350, 100], [550, 200], [350, 200]]
# [[550, 100], [350, 100], [550, 200], [350, 200]]
# Remove : [350, 100, 'BLC']
# Remove : [350, 100, 'BLC']
# [[550, 100], [350, 100], [550, 200], [350, 200]]
# Remove : [550, 200, 'BLC']
# [[550, 100], [350, 100], [550, 200], [350, 200]]
# REITERATION
# Toilettes
# [[650, 450, 'BRC'], [350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC']]
# [650, 450, 'BRC']
# [[650, 350], [450, 350], [650, 450], [450, 450]]
# Remove : [650, 350, 'BRC']
# [[650, 350], [450, 350], [650, 450], [450, 450]]
# [[650, 350], [450, 350], [650, 450], [450, 450]]
# [[650, 350], [450, 350], [650, 450], [450, 450]]
# Remove : [450, 450, 'BRC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [450, 325, 'BLC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC']]
# [450, 325, 'BLC']
# [[650, 225], [450, 225], [650, 325], [450, 325]]
# [[650, 225], [450, 225], [650, 325], [450, 325]]
# Remove : [450, 225, 'BLC']
# [[650, 225], [450, 225], [650, 325], [450, 325]]
# Remove : [650, 325, 'BLC']
# [[650, 225], [450, 225], [650, 325], [450, 325]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC']]
# [350, 100, 'BLC']
# [[550, 0], [350, 0], [550, 100], [350, 100]]
# [[550, 0], [350, 0], [550, 100], [350, 100]]
# Remove : [350, 0, 'BLC']
# [[550, 0], [350, 0], [550, 100], [350, 100]]
# Remove : [550, 100, 'BLC']
# [[550, 0], [350, 0], [550, 100], [350, 100]]
# Remove : [350, 100, 'BLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [350, 0, 'BLC'], [550, 100, 'BLC']]
# [350, 0, 'BLC']
# [[550, -100], [350, -100], [550, 0], [350, 0]]
# [[550, -100], [350, -100], [550, 0], [350, 0]]
# Remove : [350, -100, 'BLC']
# [[550, -100], [350, -100], [550, 0], [350, 0]]
# Remove : [550, 0, 'BLC']
# [[550, -100], [350, -100], [550, 0], [350, 0]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [610, 450, 'BLC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC']]
# [610, 450, 'BLC']
# [[810, 350], [610, 350], [810, 450], [610, 450]]
# [[810, 350], [610, 350], [810, 450], [610, 450]]
# Remove : [610, 350, 'BLC']
# [[810, 350], [610, 350], [810, 450], [610, 450]]
# Remove : [810, 450, 'BLC']
# [[810, 350], [610, 350], [810, 450], [610, 450]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC']]
# [550, 370, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [750, 370, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [550, 470, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [550, 350, 'BLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC']]
# [550, 350, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# Remove : [550, 250, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# Remove : [750, 350, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [750, 450, 'BLC'], [350, 270, 'TLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC']]
# [350, 270, 'TLC']
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# Remove : [550, 270, 'TLC']
# Remove : [550, 270, 'TLC']
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# [[550, 270], [350, 270], [550, 370], [350, 370]]
# Remove : [350, 370, 'TLC']
# Remove : [350, 370, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [350, 370, 'TLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC']]
# [350, 370, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [550, 370, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [350, 370, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [550, 470, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [350, 470, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, 470, 'TLC']]
# [350, -100, 'BLC']
# [[550, -200], [350, -200], [550, -100], [350, -100]]
# [[550, -200], [350, -200], [550, -100], [350, -100]]
# Remove : [350, -200, 'BLC']
# [[550, -200], [350, -200], [550, -100], [350, -100]]
# Remove : [550, -100, 'BLC']
# [[550, -200], [350, -200], [550, -100], [350, -100]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [650, 350, 'BRC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC']]
# [650, 350, 'BRC']
# [[650, 250], [450, 250], [650, 350], [450, 350]]
# Remove : [650, 250, 'BRC']
# [[650, 250], [450, 250], [650, 350], [450, 350]]
# [[650, 250], [450, 250], [650, 350], [450, 350]]
# [[650, 250], [450, 250], [650, 350], [450, 350]]
# Remove : [450, 350, 'BRC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC']]
# [350, 470, 'TLC']
# [[550, 470], [350, 470], [550, 570], [350, 570]]
# Remove : [550, 470, 'TLC']
# Remove : [550, 470, 'TLC']
# [[550, 470], [350, 470], [550, 570], [350, 570]]
# [[550, 470], [350, 470], [550, 570], [350, 570]]
# [[550, 470], [350, 470], [550, 570], [350, 570]]
# Remove : [350, 570, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [750, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC']]
# [750, 270, 'TLC']
# [[950, 270], [750, 270], [950, 370], [750, 370]]
# Remove : [950, 270, 'TLC']
# [[950, 270], [750, 270], [950, 370], [750, 370]]
# [[950, 270], [750, 270], [950, 370], [750, 370]]
# [[950, 270], [750, 270], [950, 370], [750, 370]]
# Remove : [750, 370, 'TLC']
# Remove : [750, 370, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC']]
# [750, 370, 'TLC']
# [[950, 370], [750, 370], [950, 470], [750, 470]]
# Remove : [950, 370, 'TLC']
# [[950, 370], [750, 370], [950, 470], [750, 470]]
# Remove : [750, 370, 'TLC']
# [[950, 370], [750, 370], [950, 470], [750, 470]]
# [[950, 370], [750, 370], [950, 470], [750, 470]]
# Remove : [750, 470, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [950, 370, 'TLC'], [750, 470, 'TLC']]
# [950, 370, 'TLC']
# [[1150, 370], [950, 370], [1150, 470], [950, 470]]
# Remove : [1150, 370, 'TLC']
# [[1150, 370], [950, 370], [1150, 470], [950, 470]]
# [[1150, 370], [950, 370], [1150, 470], [950, 470]]
# [[1150, 370], [950, 370], [1150, 470], [950, 470]]
# Remove : [950, 470, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [550, 470, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC']]
# [550, 470, 'TLC']
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# Remove : [750, 470, 'TLC']
# Remove : [750, 470, 'TLC']
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# Remove : [550, 470, 'TLC']
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# Remove : [550, 570, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [150, 300, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC']]
# [150, 300, 'BLC']
# [[350, 200], [150, 200], [350, 300], [150, 300]]
# [[350, 200], [150, 200], [350, 300], [150, 300]]
# Remove : [150, 200, 'BLC']
# [[350, 200], [150, 200], [350, 300], [150, 300]]
# Remove : [350, 300, 'BLC']
# [[350, 200], [150, 200], [350, 300], [150, 300]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC']]
# [550, 250, 'BLC']
# [[750, 150], [550, 150], [750, 250], [550, 250]]
# [[750, 150], [550, 150], [750, 250], [550, 250]]
# Remove : [550, 150, 'TRC']
# Remove : [550, 150, 'BLC']
# [[750, 150], [550, 150], [750, 250], [550, 250]]
# Remove : [750, 250, 'BLC']
# [[750, 150], [550, 150], [750, 250], [550, 250]]
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC']]
# [550, 470, 'TLC']
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# Remove : [750, 470, 'TLC']
# Remove : [750, 470, 'TLC']
# Remove : [750, 470, 'TLC']
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# [[750, 470], [550, 470], [750, 570], [550, 570]]
# Remove : [550, 570, 'TLC']
# Remove : [550, 570, 'TLC']
# REITERATION
# Toilettes
# [[350, 350, 'BLC'], [650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC']]
# [350, 350, 'BLC']
# [[550, 250], [350, 250], [550, 350], [350, 350]]
# [[550, 250], [350, 250], [550, 350], [350, 350]]
# Remove : [350, 250, 'BLC']
# [[550, 250], [350, 250], [550, 350], [350, 350]]
# Remove : [550, 350, 'BLC']
# [[550, 250], [350, 250], [550, 350], [350, 350]]
# Remove : [350, 350, 'BLC']
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [450, 225, 'BLC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [550, 350, 'BLC']]
# [450, 225, 'BLC']
# [[650, 125], [450, 125], [650, 225], [450, 225]]
# [[650, 125], [450, 125], [650, 225], [450, 225]]
# Remove : [450, 125, 'BLC']
# [[650, 125], [450, 125], [650, 225], [450, 225]]
# Remove : [650, 225, 'BLC']
# [[650, 125], [450, 125], [650, 225], [450, 225]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [400, 250, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [550, 350, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC']]
# [400, 250, 'TRC']
# [[400, 250], [200, 250], [400, 350], [200, 350]]
# [[400, 250], [200, 250], [400, 350], [200, 350]]
# Remove : [200, 250, 'TRC']
# Remove : [200, 250, 'TRC']
# [[400, 250], [200, 250], [400, 350], [200, 350]]
# Remove : [400, 350, 'TRC']
# [[400, 250], [200, 250], [400, 350], [200, 350]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [750, 470, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [550, 350, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC']]
# [750, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [950, 470, 'TLC']
# Remove : [950, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [750, 470, 'TLC']
# Remove : [750, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [750, 570, 'TLC']
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [550, 350, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC']]
# [550, 350, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# Remove : [750, 250, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# Remove : [550, 250, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# Remove : [750, 350, 'BLC']
# Remove : [750, 350, 'BLC']
# [[750, 250], [550, 250], [750, 350], [550, 350]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, 370, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC']]
# [350, 370, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [550, 370, 'TLC']
# Remove : [550, 370, 'TLC']
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# [[550, 370], [350, 370], [550, 470], [350, 470]]
# Remove : [350, 470, 'TLC']
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [550, 0, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 370, 'TLC'], [350, 470, 'TLC']]
# [550, 0, 'BLC']
# [[750, -100], [550, -100], [750, 0], [550, 0]]
# [[750, -100], [550, -100], [750, 0], [550, 0]]
# Remove : [550, -100, 'BLC']
# Remove : [550, -100, 'BLC']
# [[750, -100], [550, -100], [750, 0], [550, 0]]
# Remove : [750, 0, 'BLC']
# [[750, -100], [550, -100], [750, 0], [550, 0]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [550, 370, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [550, -100, 'BLC'], [750, 0, 'BLC']]
# [550, 370, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [750, 370, 'TLC']
# Remove : [750, 370, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [550, 370, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [750, 470, 'TLC']
# Remove : [750, 470, 'TLC']
# [[750, 370], [550, 370], [750, 470], [550, 470]]
# Remove : [550, 470, 'TLC']
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [0, 150, 'TRC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [550, -100, 'BLC'], [750, 0, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC']]
# [0, 150, 'TRC']
# [[0, 150], [-200, 150], [0, 250], [-200, 250]]
# [[0, 150], [-200, 150], [0, 250], [-200, 250]]
# Remove : [-200, 150, 'TRC']
# [[0, 150], [-200, 150], [0, 250], [-200, 250]]
# Remove : [0, 250, 'TRC']
# [[0, 150], [-200, 150], [0, 250], [-200, 250]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [150, 200, 'BLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [550, -100, 'BLC'], [750, 0, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [-200, 150, 'TRC'], [0, 250, 'TRC']]
# [150, 200, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# Remove : [350, 100, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# Remove : [150, 100, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# Remove : [350, 200, 'BLC']
# [[350, 100], [150, 100], [350, 200], [150, 200]]
# REITERATION
# Toilettes
# [[650, 270, 'TRC'], [400, 50, 'TLC'], [650, 150, 'TRC'], [150, 0, 'BLC'], [250, 200, 'BLC'], [450, 300, 'BLC'], [350, 50, 'TRC'], [550, 150, 'TRC'], [350, 350, 'BLC'], [750, 450, 'BLC'], [150, 370, 'TLC'], [200, 250, 'TRC'], [750, 170, 'TLC'], [550, 270, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [450, 450, 'BRC'], [650, 325, 'BLC'], [550, 100, 'BLC'], [610, 350, 'BLC'], [810, 450, 'BLC'], [750, 350, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [550, -100, 'BLC'], [650, 250, 'BRC'], [450, 350, 'BRC'], [350, 570, 'TLC'], [950, 270, 'TLC'], [750, 370, 'TLC'], [1150, 370, 'TLC'], [950, 470, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 300, 'BLC'], [550, 150, 'BLC'], [750, 250, 'BLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [350, 250, 'BLC'], [450, 125, 'BLC'], [650, 225, 'BLC'], [200, 250, 'TRC'], [400, 350, 'TRC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [550, 250, 'BLC'], [750, 350, 'BLC'], [550, 370, 'TLC'], [350, 470, 'TLC'], [550, -100, 'BLC'], [750, 0, 'BLC'], [750, 370, 'TLC'], [550, 470, 'TLC'], [-200, 150, 'TRC'], [0, 250, 'TRC'], [150, 100, 'BLC'], [350, 200, 'BLC']]
# [750, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [950, 470, 'TLC']
# Remove : [950, 470, 'TLC']
# Remove : [950, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [750, 470, 'TLC']
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# [[950, 470], [750, 470], [950, 570], [750, 570]]
# Remove : [750, 570, 'TLC']
# Remove : [750, 570, 'TLC']
# REITERATION
# Toilettes
# ...
# [150, 470, 'TLC']
# [[350, 470], [150, 470], [350, 570], [150, 570]]
# Remove : [350, 470, 'TLC']
# [[350, 470], [150, 470], [350, 570], [150, 570]]
# [[350, 470], [150, 470], [350, 570], [150, 570]]
# Remove : [350, 570, 'TLC']
# [[350, 470], [150, 470], [350, 570], [150, 570]]
# Remove : [150, 570, 'TLC']
# REITERATION
# Toilettes
# [[650, 150, 'TRC'], [450, 300, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [1150, 370, 'TLC'], [450, 125, 'BLC'], [550, 350, 'BLC'], [1150, 370, 'TLC'], [650, 150, 'BRC'], [450, 250, 'BRC'], [1150, 470, 'TLC'], [750, 370, 'TLC'], [950, 370, 'TLC'], [200, 350, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [1350, 470, 'TLC'], [350, 150, 'TRC'], [550, 250, 'TRC'], [1050, 225, 'BLC'], [350, 150, 'BLC'], [550, 250, 'BLC'], [750, 250, 'BLC'], [350, 250, 'TRC'], [1350, 470, 'TLC'], [350, 100, 'BLC'], [350, 0, 'BLC'], [550, 200, 'BLC'], [750, 100, 'BLC'], [150, 150, 'TRC'], [950, 100, 'BLC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [200, 550, 'TRC'], [350, 370, 'TLC'], [750, 250, 'BLC'], [250, 0, 'BLC'], [550, 50, 'BLC'], [550, -200, 'BLC'], [610, 50, 'BLC'], [550, 670, 'TLC'], [-250, 50, 'TRC'], [-50, 150, 'TRC'], [1050, 125, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [200, 550, 'TRC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [950, 250, 'BLC'], [-200, 450, 'TRC'], [0, 350, 'TRC'], [810, 50, 'BLC'], [550, -200, 'BLC'], [1150, 470, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [650, 0, 'BLC'], [850, 100, 'BLC'], [-200, 250, 'TRC'], [550, -200, 'BLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [850, 25, 'BLC'], [1050, 125, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [1150, 450, 'BLC'], [800, 50, 'TLC'], [-400, 250, 'TRC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [1550, 200, 'BLC'], [450, 350, 'BRC'], [400, 250, 'TLC'], [950, 470, 'TLC'], [450, 250, 'BRC'], [750, -50, 'BLC'], [950, 50, 'BLC'], [1550, 770, 'TLC'], [750, -100, 'BLC'], [950, 0, 'BLC'], [850, 25, 'BLC'], [950, -150, 'BLC'], [450, -100, 'BLC'], [650, 0, 'BLC'], [1350, -100, 'BLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [1250, 25, 'BLC'], [350, 870, 'TLC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [1550, -100, 'BLC'], [950, 250, 'BLC'], [750, 270, 'TLC'], [1010, 50, 'BLC'], [1210, 150, 'BLC'], [1350, 670, 'TLC'], [1010, 250, 'BLC'], [1210, 350, 'BLC'], [950, 300, 'BLC'], [1350, 670, 'TLC'], [650, -175, 'BLC'], [850, -75, 'BLC'], [1550, 0, 'BLC'], [1750, 100, 'BLC'], [850, -175, 'BLC'], [1050, -75, 'BLC'], [0, 550, 'TRC'], [200, 650, 'TRC'], [750, 670, 'TLC'], [550, 770, 'TLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [-200, 650, 'TRC'], [0, 750, 'TRC'], [1150, 870, 'TLC'], [-400, 250, 'TRC'], [1150, -150, 'BLC'], [1350, -50, 'BLC'], [850, 225, 'BLC'], [1050, 325, 'BLC'], [150, -200, 'BLC'], [350, -100, 'BLC'], [1550, 570, 'TLC'], [1350, 670, 'TLC'], [950, 250, 'BLC'], [1150, 350, 'BLC'], [1050, -175, 'BLC'], [1250, -75, 'BLC'], [810, 250, 'BLC'], [1010, 350, 'BLC'], [350, 50, 'BLC'], [550, 150, 'BLC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [550, 50, 'BLC'], [950, 770, 'TLC'], [750, 870, 'TLC'], [1150, 770, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [750, 670, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [550, -50, 'BLC'], [1550, 670, 'TLC'], [1350, 770, 'TLC'], [-200, 550, 'TRC'], [0, 650, 'TRC'], [1150, 250, 'BLC'], [1350, 350, 'BLC'], [550, 100, 'BLC'], [750, 200, 'BLC'], [1350, 770, 'TLC'], [1150, 870, 'TLC'], [1150, 270, 'TLC'], [950, 370, 'TLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [550, 0, 'BLC'], [750, 100, 'BLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [1150, 470, 'TLC'], [950, 570, 'TLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [750, -150, 'BLC'], [200, 850, 'TRC'], [400, 950, 'TRC'], [750, 0, 'BLC'], [950, 100, 'BLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [950, 670, 'TLC'], [750, 770, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, 770, 'TLC'], [950, 870, 'TLC'], [1150, 50, 'BLC'], [1350, 150, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, -100, 'BLC'], [1350, 0, 'BLC'], [250, 250, 'BRC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [950, -150, 'BLC'], [1150, -50, 'BLC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [-40 ...
# [550, 670, 'TLC']
# [[750, 670], [550, 670], [750, 770], [550, 770]]
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# Remove : [750, 670, 'TLC']
# [[750, 670], [550, 670], [750, 770], [550, 770]]
# Remove : [550, 670, 'TLC']
# [[750, 670], [550, 670], [750, 770], [550, 770]]
# Remove : [750, 770, 'TLC']
# Remove : [750, 770, 'TLC']
# Remove : [750, 770, 'TLC']
# Remove : [750, 770, 'TLC']
# Remove : [750, 770, 'TLC']
# Remove : [750, 770, 'TLC']
# [[750, 670], [550, 670], [750, 770], [550, 770]]
# Remove : [550, 770, 'TLC']
# Remove : [550, 770, 'TLC']
# REITERATION
# Toilettes
# [[650, 150, 'TRC'], [450, 300, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [1150, 370, 'TLC'], [450, 125, 'BLC'], [550, 350, 'BLC'], [1150, 370, 'TLC'], [650, 150, 'BRC'], [450, 250, 'BRC'], [1150, 470, 'TLC'], [750, 370, 'TLC'], [950, 370, 'TLC'], [200, 350, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [1350, 470, 'TLC'], [350, 150, 'TRC'], [550, 250, 'TRC'], [1050, 225, 'BLC'], [350, 150, 'BLC'], [550, 250, 'BLC'], [750, 250, 'BLC'], [350, 250, 'TRC'], [1350, 470, 'TLC'], [350, 100, 'BLC'], [350, 0, 'BLC'], [550, 200, 'BLC'], [750, 100, 'BLC'], [150, 150, 'TRC'], [950, 100, 'BLC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [200, 550, 'TRC'], [350, 370, 'TLC'], [750, 250, 'BLC'], [250, 0, 'BLC'], [550, 50, 'BLC'], [550, -200, 'BLC'], [610, 50, 'BLC'], [-250, 50, 'TRC'], [-50, 150, 'TRC'], [1050, 125, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [200, 550, 'TRC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [950, 250, 'BLC'], [-200, 450, 'TRC'], [0, 350, 'TRC'], [810, 50, 'BLC'], [550, -200, 'BLC'], [1150, 470, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [650, 0, 'BLC'], [850, 100, 'BLC'], [-200, 250, 'TRC'], [550, -200, 'BLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [850, 25, 'BLC'], [1050, 125, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [1150, 450, 'BLC'], [800, 50, 'TLC'], [-400, 250, 'TRC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [1550, 200, 'BLC'], [450, 350, 'BRC'], [400, 250, 'TLC'], [950, 470, 'TLC'], [450, 250, 'BRC'], [750, -50, 'BLC'], [950, 50, 'BLC'], [1550, 770, 'TLC'], [750, -100, 'BLC'], [950, 0, 'BLC'], [850, 25, 'BLC'], [950, -150, 'BLC'], [450, -100, 'BLC'], [650, 0, 'BLC'], [1350, -100, 'BLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [1250, 25, 'BLC'], [350, 870, 'TLC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [1550, -100, 'BLC'], [950, 250, 'BLC'], [750, 270, 'TLC'], [1010, 50, 'BLC'], [1210, 150, 'BLC'], [1350, 670, 'TLC'], [1010, 250, 'BLC'], [1210, 350, 'BLC'], [950, 300, 'BLC'], [1350, 670, 'TLC'], [650, -175, 'BLC'], [850, -75, 'BLC'], [1550, 0, 'BLC'], [1750, 100, 'BLC'], [850, -175, 'BLC'], [1050, -75, 'BLC'], [0, 550, 'TRC'], [200, 650, 'TRC'], [750, 670, 'TLC'], [550, 770, 'TLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [-200, 650, 'TRC'], [0, 750, 'TRC'], [1150, 870, 'TLC'], [-400, 250, 'TRC'], [1150, -150, 'BLC'], [1350, -50, 'BLC'], [850, 225, 'BLC'], [1050, 325, 'BLC'], [150, -200, 'BLC'], [350, -100, 'BLC'], [1550, 570, 'TLC'], [1350, 670, 'TLC'], [950, 250, 'BLC'], [1150, 350, 'BLC'], [1050, -175, 'BLC'], [1250, -75, 'BLC'], [810, 250, 'BLC'], [1010, 350, 'BLC'], [350, 50, 'BLC'], [550, 150, 'BLC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [550, 50, 'BLC'], [950, 770, 'TLC'], [750, 870, 'TLC'], [1150, 770, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [750, 670, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [550, -50, 'BLC'], [1550, 670, 'TLC'], [1350, 770, 'TLC'], [-200, 550, 'TRC'], [0, 650, 'TRC'], [1150, 250, 'BLC'], [1350, 350, 'BLC'], [550, 100, 'BLC'], [750, 200, 'BLC'], [1350, 770, 'TLC'], [1150, 870, 'TLC'], [1150, 270, 'TLC'], [950, 370, 'TLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [550, 0, 'BLC'], [750, 100, 'BLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [1150, 470, 'TLC'], [950, 570, 'TLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [750, -150, 'BLC'], [200, 850, 'TRC'], [400, 950, 'TRC'], [750, 0, 'BLC'], [950, 100, 'BLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [950, 670, 'TLC'], [750, 770, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, 770, 'TLC'], [950, 870, 'TLC'], [1150, 50, 'BLC'], [1350, 150, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, -100, 'BLC'], [1350, 0, 'BLC'], [250, 250, 'BRC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [950, -150, 'BLC'], [1150, -50, 'BLC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [-400, 350, 'TRC'], [-2 ...
# [1750, -100, 'BLC']
# [[1950, -200], [1750, -200], [1950, -100], [1750, -100]]
# [[1950, -200], [1750, -200], [1950, -100], [1750, -100]]
# Remove : [1750, -200, 'BLC']
# [[1950, -200], [1750, -200], [1950, -100], [1750, -100]]
# Remove : [1950, -100, 'BLC']
# [[1950, -200], [1750, -200], [1950, -100], [1750, -100]]
# REITERATION
# Toilettes
# [[650, 150, 'TRC'], [450, 300, 'BLC'], [550, 270, 'TLC'], [350, -200, 'BLC'], [1150, 370, 'TLC'], [450, 125, 'BLC'], [550, 350, 'BLC'], [1150, 370, 'TLC'], [650, 150, 'BRC'], [450, 250, 'BRC'], [1150, 470, 'TLC'], [750, 370, 'TLC'], [950, 370, 'TLC'], [200, 350, 'TRC'], [150, 0, 'BLC'], [350, 100, 'BLC'], [1350, 470, 'TLC'], [350, 150, 'TRC'], [550, 250, 'TRC'], [1050, 225, 'BLC'], [350, 150, 'BLC'], [550, 250, 'BLC'], [750, 250, 'BLC'], [350, 250, 'TRC'], [1350, 470, 'TLC'], [350, 100, 'BLC'], [350, 0, 'BLC'], [550, 200, 'BLC'], [750, 100, 'BLC'], [150, 150, 'TRC'], [950, 100, 'BLC'], [550, 470, 'TLC'], [350, 570, 'TLC'], [200, 550, 'TRC'], [350, 370, 'TLC'], [750, 250, 'BLC'], [250, 0, 'BLC'], [550, 50, 'BLC'], [550, -200, 'BLC'], [610, 50, 'BLC'], [-250, 50, 'TRC'], [-50, 150, 'TRC'], [1050, 125, 'BLC'], [350, -100, 'BLC'], [550, 0, 'BLC'], [200, 550, 'TRC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [950, 250, 'BLC'], [-200, 450, 'TRC'], [0, 350, 'TRC'], [810, 50, 'BLC'], [550, -200, 'BLC'], [1150, 470, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [650, 0, 'BLC'], [850, 100, 'BLC'], [-200, 250, 'TRC'], [550, -200, 'BLC'], [750, 270, 'TLC'], [550, 370, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [850, 25, 'BLC'], [1050, 125, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [1150, 450, 'BLC'], [800, 50, 'TLC'], [-400, 250, 'TRC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [1550, 200, 'BLC'], [450, 350, 'BRC'], [400, 250, 'TLC'], [950, 470, 'TLC'], [450, 250, 'BRC'], [750, -50, 'BLC'], [950, 50, 'BLC'], [1550, 770, 'TLC'], [750, -100, 'BLC'], [950, 0, 'BLC'], [850, 25, 'BLC'], [950, -150, 'BLC'], [450, -100, 'BLC'], [650, 0, 'BLC'], [1350, -100, 'BLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [1250, 25, 'BLC'], [350, 870, 'TLC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [1550, -100, 'BLC'], [950, 250, 'BLC'], [750, 270, 'TLC'], [1010, 50, 'BLC'], [1210, 150, 'BLC'], [1350, 670, 'TLC'], [1010, 250, 'BLC'], [1210, 350, 'BLC'], [950, 300, 'BLC'], [1350, 670, 'TLC'], [650, -175, 'BLC'], [850, -75, 'BLC'], [1550, 0, 'BLC'], [1750, 100, 'BLC'], [850, -175, 'BLC'], [1050, -75, 'BLC'], [0, 550, 'TRC'], [200, 650, 'TRC'], [750, 670, 'TLC'], [550, 770, 'TLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [-200, 650, 'TRC'], [0, 750, 'TRC'], [1150, 870, 'TLC'], [-400, 250, 'TRC'], [1150, -150, 'BLC'], [1350, -50, 'BLC'], [850, 225, 'BLC'], [1050, 325, 'BLC'], [150, -200, 'BLC'], [350, -100, 'BLC'], [1550, 570, 'TLC'], [1350, 670, 'TLC'], [950, 250, 'BLC'], [1150, 350, 'BLC'], [1050, -175, 'BLC'], [1250, -75, 'BLC'], [810, 250, 'BLC'], [1010, 350, 'BLC'], [350, 50, 'BLC'], [550, 150, 'BLC'], [950, 50, 'BLC'], [1150, 150, 'BLC'], [550, 50, 'BLC'], [950, 770, 'TLC'], [750, 870, 'TLC'], [1150, 770, 'TLC'], [200, 750, 'TRC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [810, 150, 'BLC'], [1010, 250, 'BLC'], [750, 670, 'TLC'], [750, 470, 'TLC'], [550, 570, 'TLC'], [550, -50, 'BLC'], [1550, 670, 'TLC'], [1350, 770, 'TLC'], [-200, 550, 'TRC'], [0, 650, 'TRC'], [1150, 250, 'BLC'], [1350, 350, 'BLC'], [550, 100, 'BLC'], [750, 200, 'BLC'], [1350, 770, 'TLC'], [1150, 870, 'TLC'], [1150, 270, 'TLC'], [950, 370, 'TLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [750, -200, 'BLC'], [950, -100, 'BLC'], [550, 0, 'BLC'], [750, 100, 'BLC'], [950, 570, 'TLC'], [750, 670, 'TLC'], [1150, 470, 'TLC'], [950, 570, 'TLC'], [800, 150, 'TLC'], [600, 250, 'TLC'], [750, -150, 'BLC'], [200, 850, 'TRC'], [400, 950, 'TRC'], [750, 0, 'BLC'], [950, 100, 'BLC'], [1150, 570, 'TLC'], [950, 670, 'TLC'], [950, 670, 'TLC'], [750, 770, 'TLC'], [350, 100, 'BLC'], [550, 200, 'BLC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, 770, 'TLC'], [950, 870, 'TLC'], [1150, 50, 'BLC'], [1350, 150, 'BLC'], [-200, 250, 'TRC'], [0, 350, 'TRC'], [750, 870, 'TLC'], [550, 970, 'TLC'], [1150, -100, 'BLC'], [1350, 0, 'BLC'], [250, 250, 'BRC'], [750, 250, 'BLC'], [950, 350, 'BLC'], [950, -150, 'BLC'], [1150, -50, 'BLC'], [950, 470, 'TLC'], [750, 570, 'TLC'], [1350, 570, 'TLC'], [1150, 670, 'TLC'], [-400, 350, 'TRC'], [-2 ...
# [450, 300, 'BLC']
# [[650, 200], [450, 200], [650, 300], [450, 300]]
# Remove : [650, 200, 'BLC']
# [[650, 200], [450, 200], [650, 300], [450, 300]]
# Remove : [450, 200, 'BLC']
# [[650, 200], [450, 200], [650, 300], [450, 300]]
# Remove : [650, 300, 'BLC']
# [[650, 200], [450, 200], [650, 300], [450, 300]]

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

point = Point(0.5, 0.5)
polygon = Polygon([(0, 0), (0, 0.4), (0.2, 0.4), (0.2, 1), (1, 1), (1, 0)])
print(polygon.contains(point))

# %%
plt.plot(*polygon.exterior.xy)

# %%
sizes = [(58, 206), (231, 176), (35, 113), (46, 109)]
positions = rpack.pack(sizes)
positions
poly1 = Polygon(positions)
plt.plot(*poly1.exterior.xy)
